# %%
# notebooks/02_belief_visualization.ipynb
"""
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Belief State Visualization"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "import torch\nimport numpy as np\nimport matplotlib.pyplot as plt\nfrom sklearn.decomposition import PCA\nimport sys\nsys.path.insert(0, '..')\n\nfrom src.memory.belief_state import BeliefState\n\n# Simulate belief evolution\nbelief_state = BeliefState(768, 'cpu')\nbelief_state.initialize()\n\nbeliefs = []\nfor i in range(20):\n    new_belief = torch.randn(1, 768) * 0.1 + belief_state.current_belief * 0.9\n    belief_state.update(new_belief)\n    beliefs.append(belief_state.current_belief.squeeze().numpy())\n\nbeliefs = np.array(beliefs)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# PCA visualization\npca = PCA(n_components=2)\nbeliefs_2d = pca.fit_transform(beliefs)\n\nplt.figure(figsize=(10, 8))\nplt.scatter(beliefs_2d[:, 0], beliefs_2d[:, 1], c=range(len(beliefs)), cmap='viridis')\nplt.colorbar(label='Step')\nplt.xlabel('PC1')\nplt.ylabel('PC2')\nplt.title('Belief State Evolution (PCA Projection)')\nplt.show()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
"""
