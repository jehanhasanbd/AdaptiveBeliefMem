# %%
# notebooks/01_data_exploration.ipynb
"""
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Data Exploration - LoCoMo Dataset"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "import json\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nfrom pathlib import Path\n\n# Load data\nwith open('../data/raw/locomo10.json', 'r') as f:\n    data = json.load(f)\n\nprint(f\"Total conversations: {len(data)}\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Analyze conversation structure\ndef count_sessions(conv):\n    sessions = 0\n    for turn in conv.get('log', []):\n        if 'user' in turn or 'agent' in turn:\n            sessions += 1\n    return sessions\n\nsession_counts = [count_sessions(conv) for conv in data]\n\nplt.figure(figsize=(10, 6))\nplt.hist(session_counts, bins=30, edgecolor='black')\nplt.xlabel('Number of Sessions')\nplt.ylabel('Frequency')\nplt.title('Distribution of Session Counts per Conversation')\nplt.show()\n\nprint(f\"Average sessions: {sum(session_counts)/len(session_counts):.2f}\")\nprint(f\"Max sessions: {max(session_counts)}\")\nprint(f\"Min sessions: {min(session_counts)}\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Analyze QA pairs\nqa_counts = []\nfor conv in data:\n    qa_count = len(conv.get('questions', []))\n    qa_counts.append(qa_count)\n\nprint(f\"Conversations with QA pairs: {sum(1 for c in qa_counts if c > 0)}\")\nprint(f\"Average QA pairs per conversation: {sum(qa_counts)/len(qa_counts):.2f}\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.9.0"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
"""
